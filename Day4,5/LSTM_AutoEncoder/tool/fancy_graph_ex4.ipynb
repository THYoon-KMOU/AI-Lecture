# %%
import pandas as pd
import numpy as np
data2 = pd.read_csv("/home/bg/lstm_autoencoder_trajectory/forgraph/new_expert_test.csv")

np.set_printoptions(precision=3, suppress=True)
data2.head()
data2 = data2.T
data2_pd = pd.DataFrame(data2)
data2_pd.head()
# Out:
#                 0          1          2          3          4          5     \
# brake_pressure  30.1  30.100000  30.185067  30.101580  30.200001  30.200001
# long_accel       0.2   0.197240   0.200621   0.182428   0.206763   0.202490
# steering_angle   5.9   5.813692   5.706206   5.703159   5.757476   5.736448
# wheel_speed      0.0   0.000000   0.000000   0.000000   0.000000   0.000000
#
#                      6          7          8          9     ...        2409  \
# brake_pressure  30.141415  30.100000  30.052963  30.013033  ...    1.200000
# long_accel       0.183549   0.172398   0.175268   0.202283  ...   -0.713040
# steering_angle   5.700000   5.723978   5.888716   5.700000  ... -186.999193
# wheel_speed      0.000000   0.000000   0.000000   0.000000  ...    5.521060
#
#                       2410        2411        2412        2413        2414  \
# brake_pressure    1.200000    1.200000    1.200000    1.200000    1.200000
# ...

# %%
data2 = data2_pd 
data2 = data2.T
data2 = data2[["brake_pressure", "steering_angle","long_accel", "wheel_speed"]]


data2.head()
# Out:
#    brake_pressure  steering_angle  long_accel  wheel_speed
# 0       30.100000        5.900000    0.200000          0.0
# 1       30.100000        5.813692    0.197240          0.0
# 2       30.185067        5.706206    0.200621          0.0
# 3       30.101580        5.703159    0.182428          0.0
# 4       30.200001        5.757476    0.206763          0.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 데이터 로드
data2 = pd.read_csv('/home/bg/lstm_autoencoder_trajectory/forgraph/new_expert_test.csv')
color_data = pd.read_csv('/home/bg/lstm_autoencoder_trajectory/clustered/5test9_ex.csv')

# RGB 값과 그에 해당하는 brake_pressure 데이터를 가져옴
rgb_values = color_data[['r', 'g', 'b']].values
brake_pressure_values = data2['steering_angle'].values

fig, ax = plt.subplots(figsize=(30, 7), dpi=80) 

# 이전 좌표와 색상을 저장하기 위한 변수를 초기화
old_x, old_y = 0, brake_pressure_values[0]
old_color = rgb_values[0]

for i in range(1, len(brake_pressure_values)-275):
    # 새로운 x, y 좌표와 색상을 얻음
    new_x, new_y = i, brake_pressure_values[i]
    new_color = rgb_values[i]

    # 이전 좌표에서 새로운 좌표까지 선을 그림
    ax.plot([old_x, new_x], [old_y, new_y], color=old_color, linewidth=11)

    # 이전 좌표와 색상을 업데이트함
    old_x, old_y = new_x, new_y
    old_color = new_color

# ax.grid(True)  # 격자 추가
ax.grid(axis='x', color='gray', linestyle='--', linewidth=0.5)
ax.grid(axis='y', color='gray', linestyle='--', linewidth=0.5)
plt.title('Steering angle', fontsize=16)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 데이터 로드
data2 = pd.read_csv('/home/bg/lstm_autoencoder_trajectory/forgraph/new_expert_test.csv')
color_data = pd.read_csv('/home/bg/lstm_autoencoder_trajectory/clustered/5test9_ex.csv')

# RGB 값과 그에 해당하는 brake_pressure 데이터를 가져옴
rgb_values = color_data[['r', 'g', 'b']].values
brake_pressure_values = data2['brake_pressure'].values

fig, ax = plt.subplots(figsize=(30, 7), dpi=80) 

# 이전 좌표와 색상을 저장하기 위한 변수를 초기화
old_x, old_y = 0, brake_pressure_values[0]
old_color = rgb_values[0]

for i in range(1, len(brake_pressure_values)):
    # 새로운 x, y 좌표와 색상을 얻음
    new_x, new_y = i, brake_pressure_values[i]
    new_color = rgb_values[i]

    # 이전 좌표에서 새로운 좌표까지 선을 그림
    ax.plot([old_x, new_x], [old_y, new_y], color=old_color, linewidth=11)

    # 이전 좌표와 색상을 업데이트함
    old_x, old_y = new_x, new_y
    old_color = new_color

# ax.grid(True)  # 격자 추가
ax.grid(axis='x', color='gray', linestyle='--', linewidth=0.5)
ax.grid(axis='y', color='gray', linestyle='--', linewidth=0.5)
plt.title('Brake Pressure', fontsize=16)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 데이터 로드
data2 = pd.read_csv('/home/bg/lstm_autoencoder_trajectory/forgraph/new_expert_test.csv')
color_data = pd.read_csv('/home/bg/lstm_autoencoder_trajectory/clustered/5test9_ex.csv')

# RGB 값과 그에 해당하는 brake_pressure 데이터를 가져옴
rgb_values = color_data[['r', 'g', 'b']].values
brake_pressure_values = data2['long_accel'].values

fig, ax = plt.subplots(figsize=(30, 7), dpi=80) 

# 이전 좌표와 색상을 저장하기 위한 변수를 초기화
old_x, old_y = 0, brake_pressure_values[0]
old_color = rgb_values[0]

for i in range(1, len(brake_pressure_values)):
    # 새로운 x, y 좌표와 색상을 얻음
    new_x, new_y = i, brake_pressure_values[i]
    new_color = rgb_values[i]

    # 이전 좌표에서 새로운 좌표까지 선을 그림
    ax.plot([old_x, new_x], [old_y, new_y], color=old_color, linewidth=11)

    # 이전 좌표와 색상을 업데이트함
    old_x, old_y = new_x, new_y
    old_color = new_color

# ax.grid(True)  # 격자 추가
ax.grid(axis='x', color='gray', linestyle='--', linewidth=0.5)
ax.grid(axis='y', color='gray', linestyle='--', linewidth=0.5)
plt.title('Longitudinal Acceleration', fontsize=16)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 데이터 로드
data2 = pd.read_csv('/home/bg/lstm_autoencoder_trajectory/forgraph/new_expert_test.csv')
color_data = pd.read_csv('/home/bg/lstm_autoencoder_trajectory/clustered/5test9_ex.csv')

# RGB 값과 그에 해당하는 brake_pressure 데이터를 가져옴
rgb_values = color_data[['r', 'g', 'b']].values
brake_pressure_values = data2['long_accel'].values

fig, ax = plt.subplots(figsize=(30, 7), dpi=80) 

# 이전 좌표와 색상을 저장하기 위한 변수를 초기화
old_x, old_y = 0, brake_pressure_values[0]
old_color = rgb_values[0]

for i in range(1, len(brake_pressure_values)):
    # 새로운 x, y 좌표와 색상을 얻음
    new_x, new_y = i, brake_pressure_values[i]
    new_color = rgb_values[i]

    # 이전 좌표에서 새로운 좌표까지 선을 그림
    ax.plot([old_x, new_x], [old_y, new_y], color=old_color, linewidth=7)

    # 이전 좌표와 색상을 업데이트함
    old_x, old_y = new_x, new_y
    old_color = new_color

# ax.grid(True)  # 격자 추가
ax.grid(axis='x', color='gray', linestyle='--', linewidth=0.5)
ax.grid(axis='y', color='gray', linestyle='--', linewidth=0.5)
plt.title('Longitudinal Acceleration', fontsize=16)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 데이터 로드
data2 = pd.read_csv('/home/bg/lstm_autoencoder_trajectory/forgraph/new_expert_test.csv')
color_data = pd.read_csv('/home/bg/lstm_autoencoder_trajectory/clustered/5test9_ex.csv')

# RGB 값과 그에 해당하는 brake_pressure 데이터를 가져옴
rgb_values = color_data[['r', 'g', 'b']].values
brake_pressure_values = data2['wheel_speed'].values

fig, ax = plt.subplots(figsize=(30, 7), dpi=80) 

# 이전 좌표와 색상을 저장하기 위한 변수를 초기화
old_x, old_y = 0, brake_pressure_values[0]
old_color = rgb_values[0]

for i in range(1, len(brake_pressure_values)):
    # 새로운 x, y 좌표와 색상을 얻음
    new_x, new_y = i, brake_pressure_values[i]
    new_color = rgb_values[i]

    # 이전 좌표에서 새로운 좌표까지 선을 그림
    ax.plot([old_x, new_x], [old_y, new_y], color=old_color, linewidth=11)

    # 이전 좌표와 색상을 업데이트함
    old_x, old_y = new_x, new_y
    old_color = new_color

# ax.grid(True)  # 격자 추가
ax.grid(axis='x', color='gray', linestyle='--', linewidth=0.5)
ax.grid(axis='y', color='gray', linestyle='--', linewidth=0.5)
plt.title('Wheel Speed', fontsize=16)
plt.show()
