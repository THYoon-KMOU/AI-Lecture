# %%
import pandas as pd
import numpy as np
data2 = pd.read_csv("/home/bg/lstm_autoencoder_trajectory/forgraph/new_yh_test.csv")

np.set_printoptions(precision=3, suppress=True)
data2.head()
data2 = data2.T
data2_pd = pd.DataFrame(data2)
data2_pd.head()
# Out:
#                  0          1          2          3          4          5     \
# brake_pressure  15.30  15.300000  15.300000  15.328507  15.300000  15.394190
# long_accel       0.09   0.100183   0.072262   0.092851   0.090000   0.079177
# steering_angle  14.60  14.839093  14.815522  14.828507  14.883099  14.890883
# wheel_speed      0.00   0.000000   0.000000   0.000000   0.000000   0.000000
#
#                      6          7          8          9     ...      2409  \
# brake_pressure  15.400000  15.328818  15.333708  15.035342  ...  7.409155
# long_accel       0.095681   0.085764   0.090000   0.090013  ...  0.086522
# steering_angle  14.774580  14.827199  14.891389  14.711759  ...  2.009155
# wheel_speed      0.000000   0.000000   0.000000   0.000000  ...  0.093750
#
#                     2410      2411      2412      2413     2414      2415  \
# brake_pressure  7.469578  7.496716  7.400000  7.400000  7.40000  7.400000
# long_accel      0.107722  0.086240  0.104696  0.090700  0.10000  0.076919
# steering_angle  2.000000  2.000000  2.000000  2.088211  2.16978  2.100000
# wheel_speed     0.093750  0.071736  0.062500  0.062500  0.06250  0.062500
#
#                     2416      2417      2418
# brake_pressure  7.400000  7.400000  7.400000
# long_accel      0.106362  0.076781  0.107316
# steering_angle  2.031567  2.115385  2.200000
# wheel_speed     0.062500  0.062500  0.062500
#
# [4 rows x 2419 columns]

# %%
data2 = data2_pd 
data2 = data2.T
data2 = data2[["brake_pressure", "steering_angle","long_accel", "wheel_speed"]]


data2.head()
# Out:
#    brake_pressure  steering_angle  long_accel  wheel_speed
# 0       15.300000       14.600000    0.090000          0.0
# 1       15.300000       14.839093    0.100183          0.0
# 2       15.300000       14.815522    0.072262          0.0
# 3       15.328507       14.828507    0.092851          0.0
# 4       15.300000       14.883099    0.090000          0.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 데이터 로드
data2 = pd.read_csv('/home/bg/lstm_autoencoder_trajectory/forgraph/new_yh_test.csv')
color_data = pd.read_csv('/home/bg/lstm_autoencoder_trajectory/forgraph/yh_20_stand_clus7.csv')

# RGB 값과 그에 해당하는 brake_pressure 데이터를 가져옴
rgb_values = color_data[['r', 'g', 'b']].values
brake_pressure_values = data2['steering_angle'].values

fig, ax = plt.subplots(figsize=(30, 7), dpi=80) 

# 이전 좌표와 색상을 저장하기 위한 변수를 초기화
old_x, old_y = 0, brake_pressure_values[0]
old_color = rgb_values[0]

for i in range(1, len(brake_pressure_values)):
    # 새로운 x, y 좌표와 색상을 얻음
    new_x, new_y = i, brake_pressure_values[i]
    new_color = rgb_values[i]

    # 이전 좌표에서 새로운 좌표까지 선을 그림
    ax.plot([old_x, new_x], [old_y, new_y], color=old_color, linewidth=4)

    # 이전 좌표와 색상을 업데이트함
    old_x, old_y = new_x, new_y
    old_color = new_color

# ax.grid(True)  # 격자 추가
ax.grid(axis='x', color='gray', linestyle='--', linewidth=0.5)
ax.grid(axis='y', color='gray', linestyle='--', linewidth=0.5)
plt.title('Steering angle', fontsize=16)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 데이터 로드
data2 = pd.read_csv('/home/bg/lstm_autoencoder_trajectory/forgraph/new_yh_test.csv')
color_data = pd.read_csv('/home/bg/lstm_autoencoder_trajectory/forgraph/yh_20_stand_clus7.csv')

# RGB 값과 그에 해당하는 brake_pressure 데이터를 가져옴
rgb_values = color_data[['r', 'g', 'b']].values
brake_pressure_values = data2['brake_pressure'].values

fig, ax = plt.subplots(figsize=(30, 7), dpi=80) 

# 이전 좌표와 색상을 저장하기 위한 변수를 초기화
old_x, old_y = 0, brake_pressure_values[0]
old_color = rgb_values[0]

for i in range(1, len(brake_pressure_values)):
    # 새로운 x, y 좌표와 색상을 얻음
    new_x, new_y = i, brake_pressure_values[i]
    new_color = rgb_values[i]

    # 이전 좌표에서 새로운 좌표까지 선을 그림
    ax.plot([old_x, new_x], [old_y, new_y], color=old_color, linewidth=4)

    # 이전 좌표와 색상을 업데이트함
    old_x, old_y = new_x, new_y
    old_color = new_color

# ax.grid(True)  # 격자 추가
ax.grid(axis='x', color='gray', linestyle='--', linewidth=0.5)
ax.grid(axis='y', color='gray', linestyle='--', linewidth=0.5)
plt.title('Brake Pressure', fontsize=16)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 데이터 로드
data2 = pd.read_csv('/home/bg/lstm_autoencoder_trajectory/forgraph/new_yh_test.csv')
color_data = pd.read_csv('/home/bg/lstm_autoencoder_trajectory/forgraph/yh_20_stand_clus7.csv')

# RGB 값과 그에 해당하는 brake_pressure 데이터를 가져옴
rgb_values = color_data[['r', 'g', 'b']].values
brake_pressure_values = data2['long_accel'].values

fig, ax = plt.subplots(figsize=(30, 7), dpi=80) 

# 이전 좌표와 색상을 저장하기 위한 변수를 초기화
old_x, old_y = 0, brake_pressure_values[0]
old_color = rgb_values[0]

for i in range(1, len(brake_pressure_values)):
    # 새로운 x, y 좌표와 색상을 얻음
    new_x, new_y = i, brake_pressure_values[i]
    new_color = rgb_values[i]

    # 이전 좌표에서 새로운 좌표까지 선을 그림
    ax.plot([old_x, new_x], [old_y, new_y], color=old_color, linewidth=4)

    # 이전 좌표와 색상을 업데이트함
    old_x, old_y = new_x, new_y
    old_color = new_color

# ax.grid(True)  # 격자 추가
ax.grid(axis='x', color='gray', linestyle='--', linewidth=0.5)
ax.grid(axis='y', color='gray', linestyle='--', linewidth=0.5)
plt.title('Longitudinal Acceleration', fontsize=16)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 데이터 로드
data2 = pd.read_csv('/home/bg/lstm_autoencoder_trajectory/forgraph/new_yh_test.csv')
color_data = pd.read_csv('/home/bg/lstm_autoencoder_trajectory/forgraph/yh_20_stand_clus7.csv')

# RGB 값과 그에 해당하는 brake_pressure 데이터를 가져옴
rgb_values = color_data[['r', 'g', 'b']].values
brake_pressure_values = data2['wheel_speed'].values

fig, ax = plt.subplots(figsize=(30, 7), dpi=80) 

# 이전 좌표와 색상을 저장하기 위한 변수를 초기화
old_x, old_y = 0, brake_pressure_values[0]
old_color = rgb_values[0]

for i in range(1, len(brake_pressure_values)):
    # 새로운 x, y 좌표와 색상을 얻음
    new_x, new_y = i, brake_pressure_values[i]
    new_color = rgb_values[i]

    # 이전 좌표에서 새로운 좌표까지 선을 그림
    ax.plot([old_x, new_x], [old_y, new_y], color=old_color, linewidth=10)

    # 이전 좌표와 색상을 업데이트함
    old_x, old_y = new_x, new_y
    old_color = new_color

# ax.grid(True)  # 격자 추가
ax.grid(axis='x', color='gray', linestyle='--', linewidth=0.5)
ax.grid(axis='y', color='gray', linestyle='--', linewidth=0.5)
plt.title('Wheel Speed', fontsize=16)
plt.show()
